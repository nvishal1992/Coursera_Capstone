# %% [markdown]
# ## Import the Library and fetch data from Wiki. Remove NA rows

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

source=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

raw_list = pd.read_html(source, header=0, attrs={"class":"wikitable sortable"})[0]
raw_list= pd.DataFrame(raw_list)
raw_list=raw_list.replace("Not assigned", np.nan)
raw_list.dropna(subset=['Borough'],axis=0, inplace=True)
raw_list['Neighbourhood'].fillna(raw_list['Borough'], inplace=True)
raw_list
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Queen's Park
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# ### Gouping the Neighbouthood based on Postal

# %%
raw_list_grouped=raw_list.groupby(['Postcode','Borough'])['Neighbourhood'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
raw_list_grouped = raw_list_grouped.sample(frac=1).reset_index(drop=True)
raw_list_grouped.head()
# Out:
#   Postcode           Borough  \
# 0      M6B        North York
# 1      M4A        North York
# 2      M5P   Central Toronto
# 3      M1M       Scarborough
# 4      M5V  Downtown Toronto
#
#                                        Neighbourhood
# 0                                          Glencairn
# 1                                   Victoria Village
# 2                Forest Hill North, Forest Hill West
# 3    Cliffcrest, Cliffside, Scarborough Village West
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...

# %%
raw_list_grouped.shape
# Out:
# (103, 3)

# %%
import requests
import pandas as pd
geo_file=pd.read_csv('http://cocl.us/Geospatial_data')
geo_file.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
toronto=raw_list_grouped.set_index('Postcode').join(geo_file.set_index('Postal Code'))

# %%
toronto.head()
# Out:
#                    Borough                                      Neighbourhood  \
# Postcode
# M6B             North York                                          Glencairn
# M4A             North York                                   Victoria Village
# M5P        Central Toronto                Forest Hill North, Forest Hill West
# M1M            Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# M5V       Downtown Toronto  CN Tower, Bathurst Quay, Island airport, Harbo...
#
#            Latitude  Longitude
# Postcode
# M6B       43.709577 -79.445073
# M4A       43.725882 -79.315572
# M5P       43.696948 -79.411307
# M1M       43.716316 -79.239476
# M5V       43.628947 -79.394420

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(toronto['Borough'].unique()),
        toronto.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %% [markdown]
# ### Map Generation

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2p-h14c3975_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighbourhood in zip(toronto['Latitude'], toronto['Longitude'], toronto['Borough'], toronto['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### playing with the data

# %%
mylist=toronto['Borough']
sub = 'Toronto'
listing=[sub in mystring for mystring in mylist]
TorontoDF_limited=toronto[listing].reset_index(drop=True)
TorontoDF_limited.head(12)
# Out:
#              Borough                                      Neighbourhood  \
# 0    Central Toronto                Forest Hill North, Forest Hill West
# 1   Downtown Toronto  CN Tower, Bathurst Quay, Island airport, Harbo...
# 2    Central Toronto                                 North Toronto West
# 3   Downtown Toronto  Harbourfront East, Toronto Islands, Union Station
# 4       West Toronto                      High Park, The Junction South
# 5       East Toronto                                    Studio District
# 6       West Toronto                           Little Portugal, Trinity
# 7   Downtown Toronto                           Ryerson, Garden District
# 8       West Toronto                             Parkdale, Roncesvalles
# 9   Downtown Toronto                    Stn A PO Boxes 25 The Esplanade
# 10   Central Toronto                The Annex, North Midtown, Yorkville
# 11  Downtown Toronto                                           Rosedale
#
#      Latitude  Longitude
# 0   43.696948 -79.411307
# 1   43.628947 -79.394420
# 2   43.715383 -79.405678
# 3   43.640816 -79.381752
# 4   43.661608 -79.464763
# 5   43.659526 -79.340923
# 6   43.647927 -79.419750
# 7   43.657162 -79.378937
# 8   43.648960 -79.456325
# 9   43.646435 -79.374846
# 10  43.672710 -79.405678
# 11  43.679563 -79.377529

# %%
TorontoDF_limited.shape
# Out:
# (38, 4)

# %%
print('The new dataframe has {} boroughs and {} neighborhoods.'.format(
        len(TorontoDF_limited['Borough'].unique()),
        TorontoDF_limited.shape[0]
    )
)

CLIENT_ID = 'BUNOW5XLSZ2VMWASNKEHYYNLYPKAEEJ1G1QO05CJ34WN0JK4' # your Foursquare ID
CLIENT_SECRET = 'VTKQXRIOXCQV5OSTWBRZB1B5BDLWLRLCDB3OVQE2UAGMTECJ' # your Foursquare Secret
VERSION = '20192904' # Foursquare API version

TorontoDF_limited.loc[0, 'Neighbourhood']

neighborhood_latitude = TorontoDF_limited.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = TorontoDF_limited.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = TorontoDF_limited.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# The new dataframe has 4 boroughs and 38 neighborhoods.
# Latitude and longitude values of Forest Hill North, Forest Hill West are 43.6969476, -79.41130720000001.

# %% [markdown]
# ### finding the 100 nearby venus

# %%
LIMIT=100

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            neighborhood_latitude, 
            neighborhood_longitude, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            neighborhood_latitude, 
            neighborhood_longitude, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto['Neighbourhood'],
                                   latitudes=TorontoDF_limited['Latitude'],
                                   longitudes=TorontoDF_limited['Longitude']
                                  )
# Out:
# Glencairn
# Victoria Village
# Forest Hill North, Forest Hill West
# Cliffcrest, Cliffside, Scarborough Village West
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# North Toronto West
# Clairlea, Golden Mile, Oakridge
# Islington Avenue
# Harbourfront East, Toronto Islands, Union Station
# Bathurst Manor, Downsview North, Wilson Heights
# Cedarbrae
# Woodbine Gardens, Parkview Hill
# Humber Summit
# High Park, The Junction South
# Northwest
# Studio District
# Humber Bay Shores, Mimico South, New Toronto
# Little Portugal, Trinity
# Woodbine Heights
# Ryerson, Garden District
# Thorncliffe Park
# Parkdale, Roncesvalles
# Downsview West
# Bayview Village
# Willowdale South
# Agincourt
# Fairview, Henry Farm, Oriole
# Queen's Park
# Stn A PO Boxes 25 The Esplanade
# Alderwood, Long Branch
# Willowdale West
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Westmount
# The Annex, North Midtown, Yorkville
# Northwood Park, York University
# Parkwoods
# Rosedale

# %%
len(TorontoDF_limited ['Neighbourhood'].unique())
# Out:
# 38

# %%
print(toronto_venues.shape) #venues near Toronto latitude and longitude coordinates (radius 500 m)
toronto_venues.head()
# Out:
# (152, 7)
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Glencairn              43.696948              -79.411307
# 1         Glencairn              43.696948              -79.411307
# 2         Glencairn              43.696948              -79.411307
# 3         Glencairn              43.696948              -79.411307
# 4  Victoria Village              43.696948              -79.411307
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0       Kay Gardner Beltline Trail       43.700726       -79.410101
# 1            TTC Bus #14 Glencairn       43.700221       -79.410274
# 2  Nikko Sushi Japenese Restaurant       43.700443       -79.407957
# 3                   Oliver jewelry       43.700374       -79.407644
# 4       Kay Gardner Beltline Trail       43.700726       -79.410101
#
#      Venue Category
# 0             Trail
# 1          Bus Line
# 2  Sushi Restaurant
# 3     Jewelry Store
# 4             Trail

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                               4
# Alderwood, Long Branch                                                  4
# Bathurst Manor, Downsview North, Wilson Heights                         4
# Bayview Village                                                         4
# Bloordale Gardens, Eringate, Markland Wood, Old...                      4
# CN Tower, Bathurst Quay, Island airport, Harbou...                      4
# Cedarbrae                                                               4
# Clairlea, Golden Mile, Oakridge                                         4
# Cliffcrest, Cliffside, Scarborough Village West                         4
# Cloverdale, Islington, Martin Grove, Princess G...                      4
# Downsview West                                                          4
# Fairview, Henry Farm, Oriole                                            4
# Forest Hill North, Forest Hill West                                     4
# Glencairn                                                               4
# Harbourfront East, Toronto Islands, Union Station                       4
# High Park, The Junction South                                           4
# Humber Bay Shores, Mimico South, New Toronto                            4
# Humber Summit                                                           4
# Islington Avenue                                                        4
# Little Portugal, Trinity                                                4
# North Toronto West                                                      4
# Northwest                                                               4
# Northwood Park, York University                                         4
# Parkdale, Roncesvalles                                                  4
# Parkwoods                                                               4
# Queen's Park                                                            4
# Rosedale                                                                4
# Ryerson, Garden District                                                4
# Stn A PO Boxes 25 The Esplanade                                         4
# Studio District                                                         4
# The Annex, North Midtown, Yorkville                                     4
# Thorncliffe Park                                                        4
# Victoria Village                                                        4
# Westmount                                                               4
# Willowdale South                                                        4
# Willowdale West                                                         4
# Woodbine Gardens, Parkview Hill                                         4
# Woodbine Heights                                                        4
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                                4
# Alderwood, Long Branch                                                   4
# Bathurst Manor, Downsview North, Wilson Heights                          4
# Bayview Village                                                          4
# Bloordale Gardens, Eringate, Markland Wood, Old...                       4
# CN Tower, Bathurst Quay, Island airport, Harbou...                       4
# Cedarbrae                                                                4
# Clairlea, Golden Mile, Oakridge                                          4
# Cliffcrest, Cliffside, Scarborough Village West                          4
# Cloverdale, Islington, Martin Grove, Princess G...                       4
# Downsview West                                                           4
# Fairview, Henry Farm, Oriole                                             4
# Forest Hill North, Forest Hill West                                      4
# Glencairn                                                                4
# Harbourfront East, Toronto Islands, Union Station                        4
# High Park, The Junction South                                            4
# Humber Bay Shores, Mimico South, New Toronto                             4
# Humber Summit                                                            4
# Islington Avenue                                                         4
# Little Portugal, Trinity                                                 4
# North Toronto West                                                       4
# Northwest                                                                4
# Northwood Park, York University                                          4
# Parkdale, Roncesvalles                                                   4
# Parkwoods                                                                4
# Queen's Park                                                             4
# Rosedale                                                                 4
# Ryerson, Garden District                                                 4
# Stn A PO Boxes 25 The Esplanade                                          4
# Studio District                                                          4
# The Annex, North Midtown, Yorkville                                      4
# Thorncliffe Park                                                         4
# Victoria Village                                                         4
# Westmount                                                                4
# Willowdale South                                                         4
# Willowdale West                                                          4
# Woodbine Gardens, Parkview Hill                                          4
# Woodbine Heights                                                         4
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                               4               4
# Alderwood, Long Branch                                  4               4
# Bathurst Manor, Downsview North, Wilson Heights         4               4
# Bayview Village                                         4               4
# Bloordale Gardens, Eringate, Markland Wood, Old...      4               4
# CN Tower, Bathurst Quay, Island airport, Harbou...      4               4
# Cedarbrae                                               4               4
# Clairlea, Golden Mile, Oakridge                         4               4
# Cliffcrest, Cliffside, Scarborough Village West         4               4
# Cloverdale, Islington, Martin Grove, Princess G...      4               4
# Downsview West                                          4               4
# Fairview, Henry Farm, Oriole                            4               4
# Forest Hill North, Forest Hill West                     4               4
# Glencairn                                               4               4
# Harbourfront East, Toronto Islands, Union Station       4               4
# High Park, The Junction South                           4               4
# Humber Bay Shores, Mimico South, New Toronto            4               4
# Humber Summit                                           4               4
# Islington Avenue                                        4               4
# Little Portugal, Trinity                                4               4
# North Toronto West                                      4               4
# Northwest                                               4               4
# Northwood Park, York University                         4               4
# Parkdale, Roncesvalles                                  4               4
# Parkwoods                                               4               4
# Queen's Park                                            4               4
# Rosedale                                                4               4
# Ryerson, Garden District                                4               4
# Stn A PO Boxes 25 The Esplanade                         4               4
# Studio District                                         4               4
# The Annex, North Midtown, Yorkville                     4               4
# Thorncliffe Park                                        4               4
# Victoria Village                                        4               4
# Westmount                                               4               4
# Willowdale South                                        4               4
# Willowdale West                                         4               4
# Woodbine Gardens, Parkview Hill                         4               4
# Woodbine Heights                                        4               4
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                         4
# Alderwood, Long Branch                                            4
# Bathurst Manor, Downsview North, Wilson Heights                   4
# Bayview Village                                                   4
# Bloordale Gardens, Eringate, Markland Wood, Old...                4
# CN Tower, Bathurst Quay, Island airport, Harbou...                4
# Cedarbrae                                                         4
# Clairlea, Golden Mile, Oakridge                                   4
# Cliffcrest, Cliffside, Scarborough Village West                   4
# Cloverdale, Islington, Martin Grove, Princess G...                4
# Downsview West                                                    4
# Fairview, Henry Farm, Oriole                                      4
# Forest Hill North, Forest Hill West                               4
# Glencairn                                                         4
# Harbourfront East, Toronto Islands, Union Station                 4
# High Park, The Junction South                                     4
# Humber Bay Shores, Mimico South, New Toronto                      4
# Humber Summit                                                     4
# Islington Avenue                                                  4
# Little Portugal, Trinity                                          4
# North Toronto West                                                4
# Northwest                                                         4
# Northwood Park, York University                                   4
# Parkdale, Roncesvalles                                            4
# Parkwoods                                                         4
# Queen's Park                                                      4
# Rosedale                                                          4
# Ryerson, Garden District                                          4
# Stn A PO Boxes 25 The Esplanade                                   4
# Studio District                                                   4
# The Annex, North Midtown, Yorkville                               4
# Thorncliffe Park                                                  4
# Victoria Village                                                  4
# Westmount                                                         4
# Willowdale South                                                  4
# Willowdale West                                                   4
# Woodbine Gardens, Parkview Hill                                   4
# Woodbine Heights                                                  4
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                        4
# Alderwood, Long Branch                                           4
# Bathurst Manor, Downsview North, Wilson Heights                  4
# Bayview Village                                                  4
# Bloordale Gardens, Eringate, Markland Wood, Old...               4
# CN Tower, Bathurst Quay, Island airport, Harbou...               4
# Cedarbrae                                                        4
# Clairlea, Golden Mile, Oakridge                                  4
# Cliffcrest, Cliffside, Scarborough Village West                  4
# Cloverdale, Islington, Martin Grove, Princess G...               4
# Downsview West                                                   4
# Fairview, Henry Farm, Oriole                                     4
# Forest Hill North, Forest Hill West                              4
# Glencairn                                                        4
# Harbourfront East, Toronto Islands, Union Station                4
# High Park, The Junction South                                    4
# Humber Bay Shores, Mimico South, New Toronto                     4
# Humber Summit                                                    4
# Islington Avenue                                                 4
# Little Portugal, Trinity                                         4
# North Toronto West                                               4
# Northwest                                                        4
# Northwood Park, York University                                  4
# Parkdale, Roncesvalles                                           4
# Parkwoods                                                        4
# Queen's Park                                                     4
# Rosedale                                                         4
# Ryerson, Garden District                                         4
# Stn A PO Boxes 25 The Esplanade                                  4
# Studio District                                                  4
# The Annex, North Midtown, Yorkville                              4
# Thorncliffe Park                                                 4
# Victoria Village                                                 4
# Westmount                                                        4
# Willowdale South                                                 4
# Willowdale West                                                  4
# Woodbine Gardens, Parkview Hill                                  4
# Woodbine Heights                                                 4

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 4 uniques categories.

# %% [markdown]
# ### Finding unique Venues and listing

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
#fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
col_list = list(toronto_onehot.columns)
col_list.remove('Neighborhood')
fixed_columns = ['Neighborhood'] + col_list
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
# Out:
#        Neighborhood  Bus Line  Jewelry Store  Sushi Restaurant  Trail
# 0         Glencairn         0              0                 0      1
# 1         Glencairn         1              0                 0      0
# 2         Glencairn         0              0                 1      0
# 3         Glencairn         0              1                 0      0
# 4  Victoria Village         0              0                 0      1

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Bus Line  \
# 0                                           Agincourt      0.25
# 1                              Alderwood, Long Branch      0.25
# 2     Bathurst Manor, Downsview North, Wilson Heights      0.25
# 3                                     Bayview Village      0.25
# 4   Bloordale Gardens, Eringate, Markland Wood, Ol...      0.25
# 5   CN Tower, Bathurst Quay, Island airport, Harbo...      0.25
# 6                                           Cedarbrae      0.25
# 7                     Clairlea, Golden Mile, Oakridge      0.25
# 8     Cliffcrest, Cliffside, Scarborough Village West      0.25
# 9   Cloverdale, Islington, Martin Grove, Princess ...      0.25
# 10                                     Downsview West      0.25
# 11                       Fairview, Henry Farm, Oriole      0.25
# 12                Forest Hill North, Forest Hill West      0.25
# 13                                          Glencairn      0.25
# 14  Harbourfront East, Toronto Islands, Union Station      0.25
# 15                      High Park, The Junction South      0.25
# 16       Humber Bay Shores, Mimico South, New Toronto      0.25
# 17                                      Humber Summit      0.25
# 18                                   Islington Avenue      0.25
# 19                           Little Portugal, Trinity      0.25
# 20                                 North Toronto West      0.25
# 21                                          Northwest      0.25
# 22                    Northwood Park, York University      0.25
# 23                             Parkdale, Roncesvalles      0.25
# 24                                          Parkwoods      0.25
# 25                                       Queen's Park      0.25
# 26                                           Rosedale      0.25
# 27                           Ryerson, Garden District      0.25
# 28                    Stn A PO Boxes 25 The Esplanade      0.25
# 29                                    Studio District      0.25
# 30                The Annex, North Midtown, Yorkville      0.25
# 31                                   Thorncliffe Park      0.25
# 32                                   Victoria Village      0.25
# 33                                          Westmount      0.25
# 34                                   Willowdale South      0.25
# 35                                    Willowdale West      0.25
# 36                    Woodbine Gardens, Parkview Hill      0.25
# 37                                   Woodbine Heights      0.25
#
#     Jewelry Store  Sushi Restaurant  Trail
# 0            0.25              0.25   0.25
# 1            0.25              0.25   0.25
# 2            0.25              0.25   0.25
# 3            0.25              0.25   0.25
# 4            0.25              0.25   0.25
# 5            0.25              0.25   0.25
# 6            0.25              0.25   0.25
# 7            0.25              0.25   0.25
# 8            0.25              0.25   0.25
# 9            0.25              0.25   0.25
# 10           0.25              0.25   0.25
# 11           0.25              0.25   0.25
# 12           0.25              0.25   0.25
# 13           0.25              0.25   0.25
# 14           0.25              0.25   0.25
# 15           0.25              0.25   0.25
# 16           0.25              0.25   0.25
# 17           0.25              0.25   0.25
# 18           0.25              0.25   0.25
# 19           0.25              0.25   0.25
# 20           0.25              0.25   0.25
# 21           0.25              0.25   0.25
# 22           0.25              0.25   0.25
# 23           0.25              0.25   0.25
# 24           0.25              0.25   0.25
# 25           0.25              0.25   0.25
# 26           0.25              0.25   0.25
# 27           0.25              0.25   0.25
# 28           0.25              0.25   0.25
# 29           0.25              0.25   0.25
# 30           0.25              0.25   0.25
# 31           0.25              0.25   0.25
# 32           0.25              0.25   0.25
# 33           0.25              0.25   0.25
# 34           0.25              0.25   0.25
# 35           0.25              0.25   0.25
# 36           0.25              0.25   0.25
# 37           0.25              0.25   0.25

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Alderwood, Long Branch----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Bathurst Manor, Downsview North, Wilson Heights----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Bayview Village----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Cedarbrae----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Clairlea, Golden Mile, Oakridge----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Cliffcrest, Cliffside, Scarborough Village West----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Downsview West----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Fairview, Henry Farm, Oriole----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Forest Hill North, Forest Hill West----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Glencairn----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----High Park, The Junction South----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Humber Bay Shores, Mimico South, New Toronto----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Humber Summit----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Islington Avenue----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Little Portugal, Trinity----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----North Toronto West----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Northwest----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Northwood Park, York University----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Parkdale, Roncesvalles----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Parkwoods----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Queen's Park----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Rosedale----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Ryerson, Garden District----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Studio District----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----The Annex, North Midtown, Yorkville----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Thorncliffe Park----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Victoria Village----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Westmount----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Willowdale South----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Willowdale West----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Woodbine Gardens, Parkview Hill----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
#
#
# ----Woodbine Heights----
#               venue  freq
# 0          Bus Line  0.25
# 1     Jewelry Store  0.25
# 2  Sushi Restaurant  0.25
# 3             Trail  0.25
